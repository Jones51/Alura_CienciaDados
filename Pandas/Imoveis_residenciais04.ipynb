# %% [markdown]
# # Relatório de vendas 4

# %% [markdown]
# ### Criando Novas Variáveia

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados\\aluguel.csv', sep=';')

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor Bruto
# 0  1700.0       500.0    60.0       2260.0
# 1  7000.0         NaN     NaN          NaN
# 2  5200.0      4020.0  1111.0      10331.0
# 3   800.0       390.0    20.0       1210.0
# 4   800.0       230.0     NaN          NaN

# %%
dados['m2'] = dados['Valor']/dados['Area']

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor Bruto         m2
# 0  1700.0       500.0    60.0       2260.0  42.500000
# 1  7000.0         NaN     NaN          NaN  70.000000
# 2  5200.0      4020.0  1111.0      10331.0  34.666667
# 3   800.0       390.0    20.0       1210.0  53.333333
# 4   800.0       230.0     NaN          NaN  16.666667

# %%
dados['m2'] = dados['m2'].round(2)

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor Bruto     m2
# 0  1700.0       500.0    60.0       2260.0  42.50
# 1  7000.0         NaN     NaN          NaN  70.00
# 2  5200.0      4020.0  1111.0      10331.0  34.67
# 3   800.0       390.0    20.0       1210.0  53.33
# 4   800.0       230.0     NaN          NaN  16.67

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto']/dados['Area']).round(2)

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor Bruto     m2  Valor Bruto m2
# 0  1700.0       500.0    60.0       2260.0  42.50           56.50
# 1  7000.0         NaN     NaN          NaN  70.00             NaN
# 2  5200.0      4020.0  1111.0      10331.0  34.67           68.87
# 3   800.0       390.0    20.0       1210.0  53.33           80.67
# 4   800.0       230.0     NaN          NaN  16.67             NaN

# %%
casa = ['Casa', 'Casa de Condominio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados["Tipo"].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor Bruto     m2  Valor Bruto m2  \
# 0  1700.0       500.0    60.0       2260.0  42.50           56.50
# 1  7000.0         NaN     NaN          NaN  70.00             NaN
# 2  5200.0      4020.0  1111.0      10331.0  34.67           68.87
# 3   800.0       390.0    20.0       1210.0  53.33           80.67
# 4   800.0       230.0     NaN          NaN  16.67             NaN
#
#   Tipo Agregado
# 0   Apartamento
# 1          Casa
# 2   Apartamento
# 3   Apartamento
# 4   Apartamento
